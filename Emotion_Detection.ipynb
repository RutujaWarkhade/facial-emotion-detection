# %% [markdown]
# # Import Libraries

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint,ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # 1.Data Loading and Preprocessing

# %%
data_dir = "D:/Emotion Detection/images/images"
train_dir = os.path.join(data_dir, 'train')
validation_dir = os.path.join(data_dir, 'validation')

# %%
# Image Data Generator
train_datagen = ImageDataGenerator(
    rescale=1./255, 
    rotation_range=20,
    zoom_range=0.2, 
    horizontal_flip=True
)
validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(48, 48),
    batch_size=64,
    class_mode='categorical',
    color_mode='grayscale'
)


validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(48, 48),
    batch_size=64,
    class_mode='categorical',
    color_mode='grayscale'
)
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.

# %% [markdown]
# # 2.EDA (Visualizing Some Images)

# %%
class_names = list(train_generator.class_indices.keys())

images, labels = next(train_generator)
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].reshape(48, 48), cmap='gray')
    plt.title(class_names[np.argmax(labels[i])])
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. CNN Model Architecture

# %%
model = Sequential([
    Conv2D(64, (3, 3), activation='relu', input_shape=(48, 48, 1)),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Conv2D(128, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Conv2D(256, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(2, 2),
    Dropout(0.25),

    Flatten(),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),

    Dense(7, activation='softmax')
])

model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# C:\Users\om\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 46, 46, 64)          │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 46, 46, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 23, 23, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 23, 23, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 21, 21, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 21, 21, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 10, 10, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 10, 10, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 8, 8, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 8, 8, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 4, 4, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 4096)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       2,097,664 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 7)                   │           3,591 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,474,759 (9.44 MB)
#  Trainable params: 2,472,839 (9.43 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %% [markdown]
# # 4.Model Traning

# %%
# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-6, verbose=1)

# Model Training
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    callbacks=[early_stopping, lr_scheduler]
)
# Out:
# C:\Users\om\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 203s 438ms/step - accuracy: 0.2775 - loss: 2.0969 - val_accuracy: 0.2061 - val_loss: 2.0419 - learning_rate: 0.0010
# Epoch 2/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 282s 626ms/step - accuracy: 0.3932 - loss: 1.6107 - val_accuracy: 0.3673 - val_loss: 1.6069 - learning_rate: 0.0010
# Epoch 3/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 200s 443ms/step - accuracy: 0.4421 - loss: 1.4532 - val_accuracy: 0.4737 - val_loss: 1.3987 - learning_rate: 0.0010
# Epoch 4/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 233s 517ms/step - accuracy: 0.4735 - loss: 1.3812 - val_accuracy: 0.4907 - val_loss: 1.3497 - learning_rate: 0.0010
# Epoch 5/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 187s 415ms/step - accuracy: 0.4861 - loss: 1.3511 - val_accuracy: 0.5293 - val_loss: 1.2364 - learning_rate: 0.0010
# Epoch 6/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 199s 442ms/step - accuracy: 0.4983 - loss: 1.3151 - val_accuracy: 0.5218 - val_loss: 1.2986 - learning_rate: 0.0010
# Epoch 7/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 191s 424ms/step - accuracy: 0.5094 - loss: 1.2938 - val_accuracy: 0.5535 - val_loss: 1.1907 - learning_rate: 0.0010
# Epoch 8/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 200s 444ms/step - accuracy: 0.5125 - loss: 1.2769 - val_accuracy: 0.5579 - val_loss: 1.1833 - learning_rate: 0.0010
# Epoch 9/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 197s 437ms/step - accuracy: 0.5186 - loss: 1.2641 - val_accuracy: 0.5638 - val_loss: 1.1581 - learning_rate: 0.0010
# Epoch 10/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 181s 402ms/step - accuracy: 0.5281 - loss: 1.2450 - val_accuracy: 0.4868 - val_loss: 1.3644 - learning_rate: 0.0010
# Epoch 11/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 184s 409ms/step - accuracy: 0.5329 - loss: 1.2348 - val_accuracy: 0.5654 - val_loss: 1.1466 - learning_rate: 0.0010
# Epoch 12/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 191s 424ms/step - accuracy: 0.5409 - loss: 1.2183 - val_accuracy: 0.5607 - val_loss: 1.1874 - learning_rate: 0.0010
# Epoch 13/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 198s 439ms/step - accuracy: 0.5452 - loss: 1.2048 - val_accuracy: 0.5693 - val_loss: 1.1390 - learning_rate: 0.0010
# Epoch 14/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 208s 460ms/step - accuracy: 0.5482 - loss: 1.1932 - val_accuracy: 0.5671 - val_loss: 1.1335 - learning_rate: 0.0010
# Epoch 15/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 180s 398ms/step - accuracy: 0.5507 - loss: 1.1802 - val_accuracy: 0.5641 - val_loss: 1.1453 - learning_rate: 0.0010
# Epoch 16/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 193s 427ms/step - accuracy: 0.5527 - loss: 1.1771 - val_accuracy: 0.4977 - val_loss: 1.3841 - learning_rate: 0.0010
# Epoch 17/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 180s 400ms/step - accuracy: 0.5575 - loss: 1.1638 - val_accuracy: 0.5916 - val_loss: 1.1072 - learning_rate: 0.0010
# Epoch 18/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 184s 407ms/step - accuracy: 0.5615 - loss: 1.1608 - val_accuracy: 0.4561 - val_loss: 1.5502 - learning_rate: 0.0010
# Epoch 19/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 194s 430ms/step - accuracy: 0.5648 - loss: 1.1467 - val_accuracy: 0.5958 - val_loss: 1.0756 - learning_rate: 0.0010
# Epoch 20/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 218s 482ms/step - accuracy: 0.5695 - loss: 1.1379 - val_accuracy: 0.5974 - val_loss: 1.0855 - learning_rate: 0.0010
# Epoch 21/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 198s 439ms/step - accuracy: 0.5695 - loss: 1.1336 - val_accuracy: 0.5710 - val_loss: 1.1302 - learning_rate: 0.0010
# Epoch 22/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.5722 - loss: 1.1324
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 181s 401ms/step - accuracy: 0.5735 - loss: 1.1275 - val_accuracy: 0.5662 - val_loss: 1.1718 - learning_rate: 0.0010
# Epoch 23/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 218s 483ms/step - accuracy: 0.5892 - loss: 1.0885 - val_accuracy: 0.6177 - val_loss: 1.0326 - learning_rate: 2.0000e-04
# Epoch 24/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 209s 463ms/step - accuracy: 0.5965 - loss: 1.0730 - val_accuracy: 0.6251 - val_loss: 1.0114 - learning_rate: 2.0000e-04
# Epoch 25/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 206s 456ms/step - accuracy: 0.6028 - loss: 1.0608 - val_accuracy: 0.6118 - val_loss: 1.0450 - learning_rate: 2.0000e-04
# Epoch 26/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 192s 427ms/step - accuracy: 0.6019 - loss: 1.0556 - val_accuracy: 0.6337 - val_loss: 0.9890 - learning_rate: 2.0000e-04
# Epoch 27/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 201s 446ms/step - accuracy: 0.6031 - loss: 1.0493 - val_accuracy: 0.6323 - val_loss: 0.9852 - learning_rate: 2.0000e-04
# Epoch 28/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 186s 412ms/step - accuracy: 0.6077 - loss: 1.0445 - val_accuracy: 0.6200 - val_loss: 1.0340 - learning_rate: 2.0000e-04
# Epoch 29/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 203s 450ms/step - accuracy: 0.6083 - loss: 1.0360 - val_accuracy: 0.6336 - val_loss: 0.9943 - learning_rate: 2.0000e-04
# Epoch 30/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.6062 - loss: 1.0372
# Epoch 30: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 194s 430ms/step - accuracy: 0.6065 - loss: 1.0341 - val_accuracy: 0.5879 - val_loss: 1.1162 - learning_rate: 2.0000e-04
# Epoch 31/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 191s 423ms/step - accuracy: 0.6148 - loss: 1.0271 - val_accuracy: 0.6380 - val_loss: 0.9763 - learning_rate: 4.0000e-05
# Epoch 32/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 192s 425ms/step - accuracy: 0.6147 - loss: 1.0198 - val_accuracy: 0.6350 - val_loss: 0.9785 - learning_rate: 4.0000e-05
# Epoch 33/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 194s 429ms/step - accuracy: 0.6140 - loss: 1.0199 - val_accuracy: 0.6337 - val_loss: 0.9828 - learning_rate: 4.0000e-05
# Epoch 34/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 190s 420ms/step - accuracy: 0.6164 - loss: 1.0188 - val_accuracy: 0.6354 - val_loss: 0.9756 - learning_rate: 4.0000e-05
# Epoch 35/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 189s 419ms/step - accuracy: 0.6186 - loss: 1.0218 - val_accuracy: 0.6299 - val_loss: 0.9917 - learning_rate: 4.0000e-05
# Epoch 36/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 190s 420ms/step - accuracy: 0.6188 - loss: 1.0148 - val_accuracy: 0.6387 - val_loss: 0.9705 - learning_rate: 4.0000e-05
# Epoch 37/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 189s 420ms/step - accuracy: 0.6175 - loss: 1.0152 - val_accuracy: 0.6376 - val_loss: 0.9746 - learning_rate: 4.0000e-05
# Epoch 38/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 190s 421ms/step - accuracy: 0.6174 - loss: 1.0160 - val_accuracy: 0.6391 - val_loss: 0.9702 - learning_rate: 4.0000e-05
# Epoch 39/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 190s 422ms/step - accuracy: 0.6231 - loss: 1.0111 - val_accuracy: 0.6286 - val_loss: 1.0030 - learning_rate: 4.0000e-05
# Epoch 40/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 189s 420ms/step - accuracy: 0.6194 - loss: 1.0099 - val_accuracy: 0.6377 - val_loss: 0.9725 - learning_rate: 4.0000e-05
# Epoch 41/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.6182 - loss: 1.0139
# Epoch 41: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 191s 423ms/step - accuracy: 0.6171 - loss: 1.0146 - val_accuracy: 0.6414 - val_loss: 0.9704 - learning_rate: 4.0000e-05
# Epoch 42/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 186s 411ms/step - accuracy: 0.6160 - loss: 1.0074 - val_accuracy: 0.6366 - val_loss: 0.9717 - learning_rate: 8.0000e-06
# Epoch 43/50
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 186s 412ms/step - accuracy: 0.6215 - loss: 1.0132 - val_accuracy: 0.6371 - val_loss: 0.9718 - learning_rate: 8.0000e-06

# %% [markdown]
# # 6. Evaluation - Classification Report & Confusion Matrix

# %%
# 6. Evaluation - Classification Report & Confusion Matrix
val_images, val_labels = next(validation_generator)
predictions = model.predict(val_images)
y_true = np.argmax(val_labels, axis=1)
y_pred = np.argmax(predictions, axis=1)

print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#               precision    recall  f1-score   support
#
#        angry       0.50      0.50      0.50        10
#      disgust       1.00      0.50      0.67         2
#         fear       0.60      0.55      0.57        11
#        happy       0.82      0.90      0.86        10
#      neutral       0.65      0.79      0.71        14
#          sad       0.44      0.40      0.42        10
#     surprise       1.00      0.86      0.92         7
#
#     accuracy                           0.66        64
#    macro avg       0.72      0.64      0.66        64
# weighted avg       0.66      0.66      0.65        64

# %%
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # 7. Detection System

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import numpy as np

def detect_emotion(image_path):
    img = image.load_img(image_path, target_size=(48, 48), color_mode='grayscale')
    img_array = image.img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    prediction = model.predict(img_array)
    predicted_index = np.argmax(prediction)
    predicted_class = class_names[predicted_index]
    confidence = round(prediction[0][predicted_index] * 100, 2)  # Confidence in %

    # Display the image with the predicted label and confidence
    plt.imshow(img, cmap='gray')
    plt.title(f'Predicted Emotion: {predicted_class} ({confidence}%)')
    plt.axis('off')
    plt.show()

    return predicted_class, confidence

# Example Detection
predicted_emotion, confidence = detect_emotion("D:/Emotion Detection/images/train/surprise/26.jpg")
print(f"Emotion: {predicted_emotion}, Confidence: {confidence}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# Emotion: surprise, Confidence: 74.02999877929688%

# %%
# Example Detection
print(detect_emotion("D:/Emotion Detection/images/train/happy/7.jpg"))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# ('happy', np.float32(99.77))

# %%
# Example Detection
print(detect_emotion("D:/Emotion Detection/arti.jpg"))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# ('neutral', np.float32(21.75))

# %%
# Example Detection
print(detect_emotion("D:/Emotion Detection/images/train/angry/235.jpg"))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# ('angry', np.float32(37.2))

# %%
# Example Detection
print(detect_emotion("D:/Emotion Detection/images/train/neutral/535.jpg"))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# ('neutral', np.float32(48.48))

# %% [markdown]
# # 8.Saved model

# %%
# 8. Save Model
model.save(r"D:\Emotion Detection\facial_emotion_detection_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
class_names
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
